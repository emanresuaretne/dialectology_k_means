# %%
import numpy as np
import pandas as pd
import os
from PIL import Image
import tqdm
from global_kmeans_pp import global_clustering
from sklearn.decomposition import FastICA
from scipy.spatial import distance
from time import time
from seaborn import heatmap, color_palette
import warnings
import pickle
from scipy.stats import spearmanr, kendalltau, chi2_contingency

# %%
themes = os.listdir("themed_npys")

# %%
themes
# Out:
# ['Лексика', 'Морфология', 'Морфонология', 'Синтаксис', 'Фонетика']

# %%
features = []
themes_features = {}

# %%
def preprocessing():
    def npy_to_array(t):
        file_name, theme = t
        with open(f"themed_npys/{theme}/{file_name}", 'rb') as f:
            themes_features[len(features)] = theme
            features.append(file_name.rstrip(".npy"))
            return np.load(f)

    lst_ll = []
    lst_thms = []
    lst_mps = []
    tmp_mps = []
    mp_nf = ""
    
    for theme in themes:
        tmp_thms = []
        
        lst_dr = os.listdir(f"themed_npys/{theme}")
        lst_dr = sorted(lst_dr, key=lambda x: (int(x.split(",")[0].lstrip("Том ")),
                                               float(x.split("карта ")[1].split(",")[0]),
                                               float(x.split("ареал ")[1].rstrip(".npy"))
                                              )
                       )
        
        for fl_nm in lst_dr:
            mt_tpl = fl_nm, theme
            tmp_thms.append(mt_tpl)

            lst_ll.append(mt_tpl)
            
            fl_nm_mp = fl_nm.split(", ареал")[0]
            if not mp_nf or fl_nm_mp == mp_nf:
                tmp_mps.append(mt_tpl)
            else:
                lst_mps.append(tmp_mps)
                tmp_mps = [mt_tpl]
            mp_nf = fl_nm_mp
        lst_thms.append(tmp_thms)
    lst_mps.append(tmp_mps)
    
    stck = np.stack(tuple(map(npy_to_array, lst_ll)), axis=2)
    
    total_area = np.array(Image.open('area.png'))
    zero_indices = np.where(total_area == 0)

    zeros = np.zeros(stck.shape[2])
    stck[zero_indices] = zeros
    
    stck = stck.reshape(stck.shape[0] * stck.shape[1], -1)

    positions = np.where(~np.all(stck == zeros, axis=1))[0]

    X = stck[positions]
    
    return stck, positions, X

# %%
stck, positions, X = preprocessing()

# %%
X = X.astype("int")

# %% [markdown]
# Градиент

# %%
ica = FastICA(n_components=3)
ica.fit(X)
data = ica.transform(X)

# %%
scaled_data = (data - data.min(axis=0)) / (data.max(axis=0) - data.min(axis=0)) * 255
rgb = scaled_data.astype("int")

# %%
rgb = np.hstack((rgb, np.full((X.shape[0], 1), 255)))

# %%
new_image = np.zeros((stck.shape[0], 4))
new_image[positions] = rgb
res = new_image.reshape((984, 969, 4))
res = Image.fromarray(res.astype(np.uint8))
res.save("gradient.png")

# %% [markdown]
# Кластеризация

# %%
n_clusters = 36

# %%
s = time()
model = global_clustering.GlobalKMeansPP(n_clusters=n_clusters, verbose=2)
model.fit(X)
print(time() - s)
# Out:
# Solving 2-means
# Solving 3-means
# Solving 4-means
# Solving 5-means
# Solving 6-means
# Solving 7-means
# Solving 8-means
# Solving 9-means
# Solving 10-means
# Solving 11-means
# Solving 12-means
# Solving 13-means
# Solving 14-means
# Solving 15-means
# Solving 16-means
# Solving 17-means
# Solving 18-means
# Solving 19-means
# Solving 20-means
# Solving 21-means
# Solving 22-means
# Solving 23-means
# Solving 24-means
# Solving 25-means
# Solving 26-means
# Solving 27-means
# Solving 28-means
# Solving 29-means
# Solving 30-means
# Solving 31-means
# Solving 32-means
# Solving 33-means
# Solving 34-means
# Solving 35-means
# Solving 36-means
# 11520.10983133316

# %%
clusters = model.labels_
cluster_centers = model.cluster_centers_
inertia = model.inertia_

# %%
with open('clusters.pkl', 'wb') as f:
    pickle.dump(clusters, f)

with open('cluster_centers.pkl', 'wb') as f:
    pickle.dump(cluster_centers, f)

with open('inertia.pkl', 'wb') as f:
    pickle.dump(inertia, f)

# %%
with open('clusters.pkl', 'rb') as f:
    clusters = pickle.load(f)

with open('cluster_centers.pkl', 'rb') as f:
    cluster_centers = pickle.load(f)

with open('inertia.pkl', 'rb') as f:
    inertia = pickle.load(f)

# %%
warnings.simplefilter("ignore", UserWarning)

# %%
all_cluster_centers = np.concatenate(list(cluster_centers.values()))

# %%
all_cluster_centers.shape
# Out:
# (666, 446)

# %%
data = ica.transform(all_cluster_centers)

# %%
scaled_data = (data - data.min(axis=0)) / (data.max(axis=0) - data.min(axis=0)) * 255
rgb = scaled_data.astype("int")

# %%
rgb = np.hstack((rgb, np.full((all_cluster_centers.shape[0], 1), 255)))

# %%
for i in tqdm.tqdm(range(1, n_clusters + 1)):
    nth_clusters = clusters[i]
    nth_rgb = rgb[sum(range(i)):sum(range(i + 1))]

    nth_clusters_rgb = [nth_rgb[i] for i in nth_clusters]

    new_image = np.zeros((stck.shape[0], 4))
    new_image[positions] = nth_clusters_rgb
    res = new_image.reshape((984, 969, 4))
    res = Image.fromarray(res.astype(np.uint8))
    res.save(f"{i}_clusters.png")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 36/36 [00:18<00:00,  1.94it/s]

# %% [markdown]
# Близость кластеров

# %%
nth_clusters = clusters[n_clusters]
nth_cluster_centers = cluster_centers[n_clusters]

# %%
for i in tqdm.tqdm(range(n_clusters)):
    distances = np.apply_along_axis(lambda x: distance.euclidean(nth_cluster_centers[i], x), 1, nth_cluster_centers)
    norm_distances = (distances - distances.min()) / (distances.max() - distances.min())
    cmap = color_palette("inferno_r", as_cmap=True)
    heat_rgb = cmap(norm_distances) * 255
    
    heat_clusters_rgb = [heat_rgb[i] for i in nth_clusters]

    new_image = np.zeros((stck.shape[0], 4))
    new_image[positions] = heat_clusters_rgb
    res = new_image.reshape((984, 969, 4))
    res = Image.fromarray(res.astype(np.uint8))
    res.save(f"proximity_to_{i}_out_of_{n_clusters}.png")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 36/36 [00:12<00:00,  2.87it/s]

# %% [markdown]
# Близость к прототипам

# %%
distances = np.array(list(map(lambda x: distance.euclidean(X[x], nth_cluster_centers[nth_clusters[x]]), range(X.shape[0]))))
norm_distances = (distances - distances.min()) / (distances.max() - distances.min())
cmap = color_palette("inferno_r", as_cmap=True)
heat_rgb = cmap(norm_distances) * 255

# %%
new_image = np.zeros((stck.shape[0], 4))
new_image[positions] = heat_rgb
res = new_image.reshape((984, 969, 4))
res = Image.fromarray(res.astype(np.uint8))
res.save("proximity_to_centres_of_clusters.png")

# %% [markdown]
# Границы кластеров

# %%
n_clusters = 25

# %%
nth_clusters = clusters[n_clusters]

# %%
arr = np.zeros((stck.shape[0]))
arr[positions] = nth_clusters + 1
arr = arr.reshape((984, 969))

# %%
bool_arr = (((np.roll(arr, shift=(1, 0), axis=(1, 1)) == arr) | np.logical_not(np.roll(arr, shift=(1, 0), axis=(1, 1)))) \
           & ((np.roll(arr, shift=(-1, 0), axis=(1, 1)) == arr) | np.logical_not(np.roll(arr, shift=(-1, 0), axis=(1, 1)))) \
           & ((np.roll(arr, shift=(1, 0), axis=(0, 1)) == arr) | np.logical_not(np.roll(arr, shift=(1, 0), axis=(0, 1)))) \
           & ((np.roll(arr, shift=(-1, 0), axis=(0, 1)) == arr) | np.logical_not(np.roll(arr, shift=(-1, 0), axis=(0, 1))))) \
           | np.logical_not(arr)

bool_arr = ~bool_arr

# %%
res = np.zeros(bool_arr.shape + (4,))
res[bool_arr] = np.array([255] * 4)

res = Image.fromarray(res.astype(np.uint8))
res.save("borders.png")

# %% [markdown]
# Важные признаки для кластеров

# %%
with open("areals_data.txt", "r", encoding="UTF-8") as file:
    areals_data = [_.strip("\n") for _ in file.readlines()]

# %%
I = 25

# %%
nth_clusters = clusters[I]
nth_cluster_centers = cluster_centers[I]

info = np.zeros((I, X.shape[-1]))

for n in range(I):
    wh = np.where(nth_clusters == n)
    cluster_size = len(wh[0])
    print(cluster_size)
    cluster_size = np.full(X.shape[-1], cluster_size) # размеры кластера
    intersection = X[wh].sum(axis=0) # размеры пересечений
    areal_sizes = X.sum(axis=0) # размеры ареалов
    union = areal_sizes + cluster_size - intersection # размеры объединений
    total_size = np.full(X.shape[-1], X.shape[0]) # размеры всего

    IoU = intersection / union
    info[n] = IoU
    
    top = sorted(enumerate(IoU), reverse=True, key=lambda x: x[1])
    for index, t in top[:10]:
        print(features[index], areals_data[index], t)
    print()
    
    distances = (X * IoU).sum(axis=1)
    distances = (distances - distances.min()) / (distances.max() - distances.min())
    
    cmap = color_palette("inferno", as_cmap=True)
    heat_rgb = cmap(distances) * 255
    
    new_image = np.zeros((stck.shape[0], 4))
    new_image[positions] = heat_rgb
    res = new_image.reshape((984, 969, 4))
    res = Image.fromarray(res.astype(np.uint8))
    res.save(f"proximity_{I}_{cluster_size[0]}.png")
# Out:
# 13384
# Том 3, карта 7.2, ареал 5 [jе́т]ый ([jе]ный) Волог. Вытегор. 0.44039681902160815
# Том 1, карта 11, ареал 8 употребление конструкций типа за водой 0.31258870281010503
# Том 2, карта 18.1, ареал 2 пранник 0.2894927122578681
# Том 3, карта 2.1, ареал 2 ры, лы, ли 0.276055524616876
# Том 2, карта 14, ареал 3 бел. дзяжа́, дзёжка, дёжка (неполнота материала, см. комментарий) 0.27604413736207073
# Том 1, карта 3, ареал 11 /и/: п[и], б[и] и т.п. или л\п[и], б[и] и т.п. и п[и]й, б[и]й и т.п. 0.2639467533787217
# Том 1, карта 12, ареал 4 паха́ть в значении ‘бороновать после сева' 0.23936685689673737
# Том 3, карта 12, ареал 1 употребляются формы вин.-род. п. типа бел. кароў, валоў, укр. коней, корiў, гостей 0.21786552533480602
# Том 3, карта 7.1, ареал 3 тэй, тый 0.21777487733546033
# Том 1, карта 3, ареал 5 /е/: молод[е́]й, глу[х'е́]й, глух[е́]й, и т.п. 0.21112132665917527
#
# 18126
# Том 4, карта 7.3, ареал 11 рус. тепи́нка, цепи́нка; 0.5487286683572065
# Том 4, карта 7.2, ареал 4 рус. держа́лень, держа́лка, держа́к;   укр. держа́к; 0.3237121002672565
# Том 3, карта 6, ареал 11 изоглосса расширенного <м’и> 0.3107356122090551
# Том 1, карта 14.1, ареал 1 +d'užE 0.30967509636972085
# Том 2, карта 18.1, ареал 12 велёк 0.2817951349067423
# Том 3, карта 7.1, ареал 5 э́нтот 0.27650074993895846
# Том 2, карта 11, ареал 4 отмечены конструкции только с вин. п. 0.26658095406987053
# Том 3, карта 6, ареал 12 изоглосса <им’и> после заднеязычных согласных 0.23324078816140598
# Том 2, карта 8.1, ареал 3 Р. беспредложный жены, коровы, Р. предложный, Д., М. женѣ, коровѣ (рус.) 0.22249874368853048
# Том 4, карта 2.2, ареал 5 выбор предударного гласного на месте е, ’а в зависимости от твердости/мягкости следующего согласного 0.21430711760123056
#
# 18217
# Том 4, карта 7.3, ареал 8 рус. цепе́ц, тепе́ц, кепе́ц; 0.49916229503694143
# Том 4, карта 7.2, ареал 5 рус. цеви́на, теви́на, кеви́на; 0.43883708173340646
# Том 2, карта 8.1, ареал 5 Р., Д., М. жены, коровы (рус.) 0.36394828883871255
# Том 1, карта 14.1, ареал 3 +gOrazd(O) 0.3588820862737767
# Том 2, карта 16, ареал 3 петун 0.3058865374355326
# Том 1, карта 10, ареал 3 последовательное употребление невозвратных форм вместо возвратных (он женивши) 0.30446866576255294
# Том 4, карта 7.1, ареал 4 рус. при́уз, при́узь, при́вуз; 0.3025048880363006
# Том 2, карта 7.2, ареал 2 нулевая флексия (-∅) в глаголах с наконечным ударением (например, рус. диал. он в'ис'и́, кр'ичи́) 0.27694551239559856
# Том 4, карта 3.1, ареал 4 рус. /и/ на конце слова (на стол'и́, гд'и́, дв'и́, т'еб'и́) 0.2675177801095954
# Том 2, карта 18.2, ареал 3 зель 0.24835891381345926
#
# 14939
# Том 4, карта 2.2, ареал 7 изменение предударного 'а > е, u, i независимо от следующего согласного 0.391304347826087
# Том 2, карта 9.3, ареал 3 говоры с утратой флексий зв.падежа:   а) склонение на -*ā:   редуцированные системы флексий: Катери́но! - На́д'у! Марус'у! (На́д'е! Maри́je!) и т.п.;   унифицированные системы флексий - Катери́но! На́д'о! Мари́jо! и т.п.;    б) склонение на -*o:    редуцированные системы флексий: Ива́не! Па́вле! - Васи́л' и т.п. 0.37012582871059396
# Том 2, карта 11, ареал 2 преимущественное употребление род. п. в конструкциях типа укр. уз'аў ножá, бел. знайшоў гры́ба 0.3317787105514469
# Том 2, карта 18.1, ареал 5 прач 0.3190504024099636
# Том 2, карта 12, ареал 2 бел. мне балiць галава, укр. менi (мнi) болить голова 0.306662141701039
# Том 2, карта 14, ареал 2 рус. де́жка, укр. діжка 0.2773346853610499
# Том 3, карта 1.2, ареал 10 ассимиляция по месту, способу образования в сочетании шумных согласных 0.265517307952198
# Том 4, карта 7.3, ареал 5 бел. бія́к; укр. бия́к; 0.24017477908509496
# Том 2, карта 6, ареал 2 <Š ~ S'/S> = <1 л. ед.> ~ <2, 3 л. ед., 1, 2, 3 л. мн.>, например, рус. лит. плачу́ ~ пла́тишь..., пла́тят; вожу́ ~ во́зишь..., во́зят; ношу́ ~ но́сишь..., но́сят; (но только укр. диал. хо́джу́ ~ хо́диш...., хо́д'ат') 0.2373036916173771
# Том 3, карта 4.1, ареал 3 Переходное смягчение заднеязычных согласных перед окончанием счетной формы существительных а-склонения и о-склонения среднего рода, восходящим к окончанию nom.-acc. dualis: отмечено у существительных о-склонения среднего рода (укр. дв'í jáблуц'i, бел. д'з'в'é в'éц'e), 0.22789243686476046
#
# 16169
# Том 4, карта 7.3, ареал 9 рус. цепе́ц, цепи́льник, цепни́к; 0.4439308462238399
# Том 2, карта 4.1, ареал 5 Формы глаголов типа рус. бол[е́]ш, бол[е́]т, бол[е́]м и т.п. 0.411917482932621
# Том 4, карта 2.2, ареал 5 выбор предударного гласного на месте е, ’а в зависимости от твердости/мягкости следующего согласного 0.3033075610890804
# Том 2, карта 4.1, ареал 7 Формы глаголов типа рус. м[о]ш, м[о]т, м[о]м и т.п., торг[у́]ш, торг[у́]т, торг[у́]м и т.п. 0.2928687098902417
# Том 3, карта 7.1, ареал 5 э́нтот 0.20856095823012452
# Том 3, карта 6, ареал 12 изоглосса <им’и> после заднеязычных согласных 0.19686439092197064
# Том 2, карта 8.1, ареал 13 Р. с предлогом у: у женѣ, у коровѣ (у рукѣ, у землѣ) (рус.) 0.196788071171999
# Том 2, карта 16, ареал 6 кочет 0.18012249794784366
# Том 2, карта 4.1, ареал 1 Формы глаголов типа рус. зн[а]ш, зн[а]т, зн[а]м и т.п. 0.14739719665625264
# Том 3, карта 1.2, ареал 5 допустимость мягких губных согласных на конце слова 0.13286713286713286
#
# 28387
# Том 4, карта 2.2, ареал 8 изменение предударного ’а > е, i перед мягким согласным 0.6455054479418886
# Том 2, карта 18.1, ареал 22 палка 0.5954781870289778
# Том 1, карта 4, ареал 8 *’а, *ę > Е (перед мягким согласным) // А (перед твердым согласным); примеры: p'ét', p’átyj, s’ádu, s’éd’eš, instr. pn’émi, dat. pn’ám, gul’él’i, gul’át, s’c'és’jö ‘счастье’ 0.4556282067905236
# Том 4, карта 7.3, ареал 13 рус. бато́г, бадо́г; 0.4227085935661399
# Том 4, карта 7.1, ареал 2 рус. молоти́ло; 0.3521647990476437
# Том 3, карта 3.1, ареал 4 Нестяженные окончания без [j] (зона преимущественного распространения):   -[аа], -[yy] -[оо], -[ое], -[оа], -[ые], -[ие] и др.    (рус. молод[а́a] и т.п., но́в[аа] и т.п., молод[у́у] и т.п., но́в[уу] и т.п., молод[о́e], молод[о́o] или молод[о́a] и т.п., кра́сн[ое], кра́сн[оо] или кра́сн[оа] и т.п., молод[ы́е], глу[х'и́е] и т.п., но́в[ые], си́[н'ие] и т.п.). 0.3478671127286987
# Том 1, карта 2, ареал 4 л → у в позициях перед согласным и на конце слова 0.32866828810956966
# Том 3, карта 11, ареал 2 конструкции типа корова подоено 0.3273539335388499
# Том 3, карта 11, ареал 1 конструкция типа корову подоено 0.32106706799038764
# Том 3, карта 6, ареал 4 ударная субстантивная флексия <áм’и>; безударная субстантивная флексия <има>; адъективная флексия <има> 0.3125022017120513
#
# 15799
# Том 2, карта 5, ареал 5 <Р’> = <1, 2, 3 л. ед., 1, 2, 3 л. мн.>, например, рус. диал. л'уб'у́ ~ л'у́б'иш..., л'у́б'ат' 0.402583706828368
# Том 2, карта 18.1, ареал 3 пральник 0.39290841228825724
# Том 4, карта 6.6, ареал 3  — зона диссимилятивного аканья на русской территории (см. [ДАРЯ, 1,  карта № 2]). 0.38857272360999195
# Том 2, карта 8.1, ареал 12 Р. предложный, М., женѣ, коровѣ, Р. беспредложный, Д. жены, коровы (рус.) 0.35956076618229854
# Том 3, карта 12, ареал 7 формы вин.-им. п. отмечены в единичных пунктах (не картографировано): рус. кони поить, коровы доить 0.32618683001531396
# Том 4, карта 2.1, ареал 7 при диссимилятивном аканье изменение ъ/ы в у в соседстве с губными (веляризованными) согласными 0.31303163395785844
# Том 3, карта 4.1, ареал 7 В говорах с различением твердой и мягкой разновидностей склонения основы на заднеязычные согласные присоединяют: окончание твердой разновидности склонения -е (в Р. ед. числа с предлогами, М. ед. числа, по говорам - также и в Д. ед. числа); 0.270520273481774
# Том 2, карта 9.3, ареал 6 говоры, в которых в склонении на -*ā регулярно употребляются зв. формы с дифтонгическим удлинением флективного гласного:   Ма́шо́у! Ва́н'о́у! и т.п.; Ма́ша́й! Ва́н'е́й! и т.п.,    а также др. виды дифтонгического удлинения; 0.2631257164692396
# Том 3, карта 1.1, ареал 5 неразличение предударных а и о по модели диссимилятивного аканья 0.25484355444305384
# Том 1, карта 5, ареал 7 [к, г, ɣ, h] ~ [к’, к., г’, ɣ’, h’...] = <1 л. ед., 3 л. мн.> ~ <2, 3 л. ед., 1, 2 л. мн.> 0.24847090978784395
#
# 6982
# Том 2, карта 5, ареал 2 <Рl' ~ Р> = <1 л. ед.> ~ <2, 3 л. ед., 1, 2, 3 л. мн.>, например, укр. диал. л'убл'у́ ~ л'у́биш..., л'у́бет' (л'у́бит') 0.38171401289090473
# Том 4, карта 2.2, ареал 7 изменение предударного 'а > е, u, i независимо от следующего согласного 0.3200858011082643
# Том 3, карта 7.2, ареал 10 сей ([сей] и [с'ей]) 0.28298397040690504
# Том 3, карта 7.2, ареал 14 ареал сплошного употребления о́той, о́цей 0.2740104084529254
# Том 2, карта 8.1, ареал 18 Р., Д., М. землѣ (полесск. земл'iе) 0.1713126007282278
# Том 2, карта 18.2, ареал 4 скарада, скорода 0.15153309646006052
# Том 1, карта 11, ареал 7 преимущественно употребление конструкций типа за бацькам, за лiкарем 0.12610915580231002
# Том 3, карта 13.1, ареал 3 репрезентанты sošnik 0.1256498804599446
# Том 1, карта 3, ареал 3 /и/: молод[ы́], глу[х'и́], глух[ы́] и т.п. 0.11992362645613884
# Том 2, карта 18.1, ареал 5 прач 0.11745912836557529
#
# 13948
# Том 2, карта 13, ареал 6 преимущественное употребление конструкций типа укр. двi руцi 0.6906749681618791
# Том 2, карта 1.1, ареал 9 ареал, где, по данным ОЛА, наиболее высока частота протезы перед о 0.40566458519179305
# Том 2, карта 1.1, ареал 4 варьирование заднеязычной протезы и отсутствия протезы (γ, h//∅) 0.40237254132321515
# Том 2, карта 13, ареал 4 то же при отсутствии точных картографированных данных 0.3812113923358662
# Том 3, карта 4.1, ареал 5 Переходное смягчение заднеязычных согласных перед окончанием счетной формы существительных а-склонения и о-склонения среднего рода, восходящим к окончанию nom.-acc. dualis: только перед ударенными окончаниями счетной формы существительных а-склонения (укр. дв'í руц'í, дв'í д'iвк(')и, полесск., бел. дв'ié руц'ié, дв'ié д'iéвк'i, бел. д'з'в'é руцэ́, д'з'в'é д'з'éўк'i). 0.373919729355682
# Том 2, карта 12, ареал 3 укр. мене болить голова 0.3712724789437742
# Том 4, карта 7.3, ареал 5 бел. бія́к; укр. бия́к; 0.33274473606763516
# Том 3, карта 5.1, ареал 2 *-ě  в твердой разновидности а-склонения с ударенными окончаниями, *-i в том же классе слов с безударными окончаниями (укр. дв'í руц'í, дв'í д'iвки, поллеск. дв'ié руц'ié, дв'ié д'iéвк'i, бел. д'з'в'é руцэ́, д'з'в'é д'з'éўк'i); 0.31885263496833743
# Том 1, карта 11, ареал 7 преимущественно употребление конструкций типа за бацькам, за лiкарем 0.29343326506601597
# Том 3, карта 1.2, ареал 10 ассимиляция по месту, способу образования в сочетании шумных согласных 0.2722238644201399
#
# 7706
# Том 4, карта 7.3, ареал 7 укр. би́лень; 0.86702740041446
# Том 3, карта 13.1, ареал 6 укр. залiзо (+ Adj.) 0.5737810369226811
# Том 3, карта 14.1, ареал 3 mur-аn-ъk-(ъ)/ mur-jan-ъk-(ъ)/ mur-an-ъk-ьl-(ь) 0.5709002805406784
# Том 2, карта 8.1, ареал 14 Р. землѣ, Д.-М. земли (укр.: зем[л'i], зем[ли], или полесск. зем[л'iе], зем[лi]) 0.5134937029386286
# Том 3, карта 4.1, ареал 6 Переходное смягчение заднеязычных согласных перед окончанием именительного падежа множественного числа о-склонения мужского рода, восходящим к *i (укр. вóвци (вóвц'i). 0.4781205627985026
# Том 4, карта 6.1, ареал 3 -ме (несéмé, ка́жеме, ро́биме). 0.4599013755515183
# Том 3, карта 5.1, ареал 6 *-ě в форме числительного среднего рода *dъvě за пределами ареала сохранения форм nom.-acc. du. у существительных среднего рода (укр. двi). 0.43606393606393606
# Том 2, карта 10, ареал 3 бел. по лясох, укр. по лiсох 0.3864591784054871
# Том 2, карта 12, ареал 4 укр. болит н'а голова 0.38517946738710923
# Том 2, карта 4.2, ареал 3 Формы глаголов 1 л. ед.ч. и 3 л. мн.ч. типа укр. ду́ма[в]у, ду́ма[в]ут и т.п. 0.37213740458015265
#
# 26388
# Том 4, карта 7.2, ареал 9 отмечены различные наименования:   бато́г, падо́г, че́рен, черено́к, па́лка, ка́дка 0.47472324723247233
# Том 2, карта 14, ареал 5 рус. квашо́нка 0.3939784946236559
# Том 1, карта 5, ареал 5 <К> - во всех формах парадигмы (например, пеку́, пеко́ш...) 0.3925831851663703
# Том 4, карта 7.3, ареал 14 рус. па́лка; 0.3716954348139157
# Том 4, карта 7.1, ареал 2 рус. молоти́ло; 0.33665871183965157
# Том 3, карта 11, ареал 4 конструкции типа корову подоено — единичные случаи употребления 0.31727378073357515
# Том 3, карта 8.1, ареал 2 /кчи/, /гчи/ – пекчи́, берекчи́/бераг(х)чы 0.27076782107082614
# Том 3, карта 3.1, ареал 4 Нестяженные окончания без [j] (зона преимущественного распространения):   -[аа], -[yy] -[оо], -[ое], -[оа], -[ые], -[ие] и др.    (рус. молод[а́a] и т.п., но́в[аа] и т.п., молод[у́у] и т.п., но́в[уу] и т.п., молод[о́e], молод[о́o] или молод[о́a] и т.п., кра́сн[ое], кра́сн[оо] или кра́сн[оа] и т.п., молод[ы́е], глу[х'и́е] и т.п., но́в[ые], си́[н'ие] и т.п.). 0.25432371217840755
# Том 4, карта 8.2, ареал 3 рус диал. суслон 0.2499092991676255
# Том 4, карта 6.5, ареал 3 [k] — в формах типо пекóм, береуóм; 0.24841816789586105
#
# 26296
# Том 4, карта 7.1, ареал 5 рус. при́вяз, при́вязь; 0.6050599732186103
# Том 1, карта 10, ареал 3 последовательное употребление невозвратных форм вместо возвратных (он женивши) 0.42825585064859567
# Том 2, карта 8.1, ареал 5 Р., Д., М. жены, коровы (рус.) 0.36689744444662364
# Том 2, карта 18.1, ареал 21 палица 0.33456991951710263
# Том 1, карта 12, ареал 3 паха́ть в значении ‘мести пол, двор, улицу' 0.31634023428670205
# Том 2, карта 16, ареал 3 петун 0.3035327624212395
# Том 3, карта 14.2, ареал 1 суфф. =аš= (mur-aš-ь, sik-aš-ь) 0.2971458716096993
# Том 3, карта 11, ареал 1 конструкция типа корову подоено 0.2911602143124947
# Том 3, карта 11, ареал 2 конструкции типа корова подоено 0.2893474838042812
# Том 1, карта 14.1, ареал 3 +gOrazd(O) 0.2840939935631471
#
# 33649
# Том 1, карта 8, ареал 6 зона разреженного распространения -ми 0.6561271184491917
# Том 1, карта 8, ареал 3 зона разреженного распространения -м'а 0.344100144748834
# Том 3, карта 11, ареал 4 конструкции типа корову подоено — единичные случаи употребления 0.3180521837509133
# Том 3, карта 8.1, ареал 1 /∅чи/ – пéчи́, берéчи́ 0.2865382094638878
# Том 4, карта 2.2, ареал 6 произношение 'о в предударном слоге 0.2653920962291717
# Том 3, карта 1.2, ареал 5 допустимость мягких губных согласных на конце слова 0.2519301752067181
# Том 1, карта 13, ареал 4 рус. ра́дуга-дуга́, дуга́-ра́дуга, ра́дова-дуга́; 0.2507279803949834
# Том 4, карта 7.2, ареал 7 рус. ка́дка, ка́дца, ка́дочка, каду́шка; 0.24219996778963704
# Том 4, карта 7.3, ареал 12 рус. молоти́ло, молоти́лка; 0.2398204701091986
# Том 2, карта 4.1, ареал 5 Формы глаголов типа рус. бол[е́]ш, бол[е́]т, бол[е́]м и т.п. 0.23910036146191263
#
# 10934
# Том 4, карта 2.2, ареал 4 еканье 0.6085265034851678
# Том 1, карта 5, ареал 2 <К ~ Č> = <1 л. ед., 1 л. мн., 3 л. мн.> ~ <2, 3 л. ед., 2 л. мн.> (например, пеку́, пеко́м, пеку́т ~ печ'о́ш...) 0.5965281430825881
# Том 3, карта 7.2, ареал 5 [jе́т]ый ([jе]ный) Волог. Вытегор. 0.369778215061698
# Том 1, карта 13, ареал 10 рус. веселу́ха; бел. вяселу́ха; укр. веселу́ха; 0.31280128548473485
# Том 4, карта 6.5, ареал 3 [k] — в формах типо пекóм, береуóм; 0.2899467376830892
# Том 3, карта 4.1, ареал 5 Переходное смягчение заднеязычных согласных перед окончанием счетной формы существительных а-склонения и о-склонения среднего рода, восходящим к окончанию nom.-acc. dualis: только перед ударенными окончаниями счетной формы существительных а-склонения (укр. дв'í руц'í, дв'í д'iвк(')и, полесск., бел. дв'ié руц'ié, дв'ié д'iéвк'i, бел. д'з'в'é руцэ́, д'з'в'é д'з'éўк'i). 0.2890738620540273
# Том 2, карта 18.2, ареал 4 скарада, скорода 0.2868454201907504
# Том 3, карта 13.1, ареал 3 репрезентанты sošnik 0.27224556224215585
# Том 2, карта 8.1, ареал 18 Р., Д., М. землѣ (полесск. земл'iе) 0.271712158808933
# Том 3, карта 5.1, ареал 2 *-ě  в твердой разновидности а-склонения с ударенными окончаниями, *-i в том же классе слов с безударными окончаниями (укр. дв'í руц'í, дв'í д'iвки, поллеск. дв'ié руц'ié, дв'ié д'iéвк'i, бел. д'з'в'é руцэ́, д'з'в'é д'з'éўк'i); 0.2305497026111541
#
# 21741
# Том 4, карта 7.3, ареал 10 рус. тепе́ц, тепо́к; 0.7679688946491391
# Том 3, карта 1.1, ареал 6 нулевая редукция безударных гласных 0.5880278611604931
# Том 1, карта 10, ареал 4 редкое употребление невозвратных форм 0.5634387187785246
# Том 3, карта 7.1, ареал 5 э́нтот 0.394741142929779
# Том 2, карта 11, ареал 4 отмечены конструкции только с вин. п. 0.3217028454743197
# Том 3, карта 6, ареал 12 изоглосса <им’и> после заднеязычных согласных 0.2962877156640955
# Том 1, карта 14.2, ареал 3 /+ dobrE 0.29571106094808125
# Том 3, карта 6, ареал 11 изоглосса расширенного <м’и> 0.2893926284824364
# Том 1, карта 14.1, ареал 1 +d'užE 0.27655009654580565
# Том 2, карта 16, ареал 6 кочет 0.2568222780697078
#
# 14588
# Том 4, карта 2.1, ареал 7 при диссимилятивном аканье изменение ъ/ы в у в соседстве с губными (веляризованными) согласными 0.4028285783955133
# Том 3, карта 1.1, ареал 5 неразличение предударных а и о по модели диссимилятивного аканья 0.3542618276444371
# Том 4, карта 6.6, ареал 3  — зона диссимилятивного аканья на русской территории (см. [ДАРЯ, 1,  карта № 2]). 0.3419926346172987
# Том 3, карта 12, ареал 7 формы вин.-им. п. отмечены в единичных пунктах (не картографировано): рус. кони поить, коровы доить 0.33028115413889336
# Том 3, карта 13.1, ареал 2 преимущественное распространение рефлексов слав. *lеmеšь 0.3257031058938616
# Том 4, карта 7.2, ареал 3 рус. цепильно́, цепилно́; 0.3178747094751635
# Том 3, карта 7.2, ареал 2 [jе́]тот, [йе́н]тот ОЛА 689, 705 0.27795398344264055
# Том 3, карта 6, ареал 6 ударная субстантивная флексия <áми>; безударная субстантивная флексия <ами>; адъективная флексия <ими> 0.27782086079875923
# Том 1, карта 3, ареал 5 /е/: молод[е́]й, глу[х'е́]й, глух[е́]й, и т.п. 0.2728814732761008
# Том 3, карта 7.1, ареал 3 тэй, тый 0.25053330747600117
#
# 15735
# Том 4, карта 7.3, ареал 3 рус. бичу́к, би́чик; бел. бічу́к, біцу́к, бíчык; 0.2669056717186896
# Том 4, карта 2.2, ареал 5 выбор предударного гласного на месте е, ’а в зависимости от твердости/мягкости следующего согласного 0.1926069641580721
# Том 2, карта 4.2, ареал 1 Формы глаголов 1 л. ед.ч. и 3 л. мн.ч. типа рус. рабо́т[у], рабо́т[у]т и т.п. 0.1827043944485775
# Том 2, карта 11, ареал 4 отмечены конструкции только с вин. п. 0.1577133646444154
# Том 2, карта 8.1, ареал 4 Р. (ударное окончание) жены, Р. (безударное окончание) коровѣ, Д., М. женѣ, коровѣ (рус.) 0.1500828379300263
# Том 2, карта 8.1, ареал 13 Р. с предлогом у: у женѣ, у коровѣ (у рукѣ, у землѣ) (рус.) 0.14097420053765597
# Том 3, карта 6, ареал 12 изоглосса <им’и> после заднеязычных согласных 0.1354578119823654
# Том 3, карта 4.1, ареал 2 Отсутствие переходного смягчения заднеязычных согласных в тех же случаях (бел. рук'é, наг'é, стрáх'е, бóк'е, рус. рук'é, ног'é, му́х'е, стрáх'е, враг'é, бóк'е, укр. рук'í, ног'í, бóк'i). 0.11990781535958787
# Том 2, карта 18.1, ареал 11 валёк 0.11899791231732777
# Том 4, карта 2.1, ареал 2 недиссимилятивное аканье 0.11879167126396924
#
# 30852
# Том 2, карта 4.1, ареал 2 Формы голько 3 л. ед.ч. глаголов типа укр. зн[а] и т.п. 0.8123697876177742
# Том 2, карта 4.1, ареал 4 Формы только 3 л. ед.ч. глаголов типа укр. спíв[а] и т.п. 0.8123697876177742
# Том 2, карта 9.3, ареал 1 склонения на -*ā - Катери́но! - На́д'у! - Mapи́jе! и т.п. 0.707540902940091
# Том 2, карта 8.1, ареал 17 Р., Д., М. землѣ (рус. земле, укр. землi) 0.4655148938745253
# Том 3, карта 7.2, ареал 14 ареал сплошного употребления о́той, о́цей 0.4602349516581765
# Том 4, карта 2.1, ареал 5 сужение предударного о > у перед слогом с í, ý 0.43720258327668254
# Том 4, карта 3.1, ареал 2 укр. /i/ (л'iс, д'îло, в д'îл'i, б'îлит', на стол'î) 0.40763484594731103
# Том 2, карта 5, ареал 3 <Рl' ~ Р'/Р> = <1 л. ед., 3 л. мн.> ~ <2, 3 л. ед.. 1, 2 л. мн.>, например, укр. лит. люблю ~ люблять..., любиш... 0.4025153943704323
# Том 4, карта 2.2, ареал 1 артикуляционное сближение по уровню подъема предударных и, е 0.40183130144836926
# Том 4, карта 8.2, ареал 6 укр. копа и дериваты 0.399885939444214
#
# 7583
# Том 2, карта 13, ареал 3 отмечены (наряду с конструкциями, указанными в п. 2) конструкции типа бел. двух брато́ў, укр. двох хлопцiв 0.4649489481258137
# Том 3, карта 6, ареал 7 ударная субстантивная флексия <áма>; безударная субстантивная флексия <ама>; адъективная флексия <ими> 0.3464950843257933
# Том 4, карта 8.2, ареал 5 продолжения нем. Mandel 0.3178385512134321
# Том 3, карта 13.1, ареал 4 бел. нарог 0.24642903101273966
# Том 3, карта 7.2, ареал 4 ге́той 0.2422904273566658
# Том 3, карта 5.1, ареал 5 *-i  в мягкой разновидности а-склонения под ударением (укр. дв'í земли́, поллеск. дв'ié земл'í, бел. дз'в'é з'амл'í, рус. дв'é з'амл'и́); 0.2411170576636755
# Том 1, карта 13, ареал 14 бел. тэ́нча; укр. те́нча; 0.20904501763363528
# Том 2, карта 12, ареал 2 бел. мне балiць галава, укр. менi (мнi) болить голова 0.20090566462282725
# Том 1, карта 3, ареал 11 /и/: п[и], б[и] и т.п. или л\п[и], б[и] и т.п. и п[и]й, б[и]й и т.п. 0.19906700130947186
# Том 2, карта 1.2, ареал 4 варьирование заднеязычной протезы и отсутствия протезы (γ, h//∅) 0.1970890410958904
#
# 10425
# Том 3, карта 5.1, ареал 10 Отмечены рефлексы окончания *-ě счетной формы у существительных а-склонения с основами, оканчивающимися на заднеязычные и/или мягкие согласные, а также на твердые согласные и ударением на основе (д'в'é рук'é, д'в'é c'амjé, д'в'é бáб'е). 0.49003823706983296
# Том 4, карта 7.1, ареал 4 рус. при́уз, при́узь, при́вуз; 0.4516724701909887
# Том 3, карта 13.2, ареал 6 рефлексы слав. *kridlo 0.30080773833266855
# Том 3, карта 4.1, ареал 8 В говорах с различением твердой и мягкой разновидностей склонения основы на заднеязычные согласные присоединяют: окончания мягкой разновидности склонения: -е или -е наряду с -и (в Р., Д., М. ед. числа, счетной форме); 0.2977487868904622
# Том 2, карта 18.1, ареал 10 пралень 0.2695061367621274
# Том 4, карта 7.2, ареал 5 рус. цеви́на, теви́на, кеви́на; 0.26324129651860745
# Том 4, карта 2.2, ареал 2 сильное яканье 0.25165511534085033
# Том 4, карта 7.3, ареал 8 рус. цепе́ц, тепе́ц, кепе́ц; 0.23267209357464633
# Том 3, карта 5.1, ареал 8 Окончание -е счетной формы у существительных а-склонения с основой на твердый согласный и ударенными окончаниями - независимо от его происхождения (д'в'é  жен'é, д'в'é  рук'é). 0.23226643598615918
# Том 1, карта 3, ареал 7 /е/: м[е́]ю, м[е́]ешь, кр[е́]ем и т.п. 0.2216903892177856
#
# 12269
# Том 3, карта 7.1, ареал 4 [ɣэ́]ный, ([ɣэ́]ндой ДАБМ - 121) 0.5395448914390037
# Том 3, карта 10, ареал 3 /ст’и/ – клáс’т’и, с’éс’т’и 0.44063956781248637
# Том 3, карта 7.2, ареал 4 ге́той 0.4193146417445483
# Том 4, карта 7.3, ареал 4 рус. обичёвка; бел. абічо́ўка, бічо́ўка; 0.40212171970965943
# Том 3, карта 13.1, ареал 4 бел. нарог 0.37978410206084395
# Том 4, карта 7.2, ареал 2 рус. цепови́льня;   бел. цапавíла, цапавíдла, цапавíльня 0.35117120548466957
# Том 1, карта 12, ареал 4 паха́ть в значении ‘бороновать после сева' 0.27942293090356873
# Том 3, карта 2.1, ареал 2 ры, лы, ли 0.25305777282758907
# Том 2, карта 14, ареал 3 бел. дзяжа́, дзёжка, дёжка (неполнота материала, см. комментарий) 0.25304733422708053
# Том 2, карта 12, ареал 2 бел. мне балiць галава, укр. менi (мнi) болить голова 0.2503760390552843
#
# 9610
# Том 3, карта 7.2, ареал 3 той 0.540392358433993
# Том 3, карта 7.1, ареал 7 та́мтой 0.5036884036588964
# Том 3, карта 4.1, ареал 4 Переходное смягчение заднеязычных согласных перед окончанием счетной формы существительных а-склонения и о-склонения среднего рода, восходящим к окончанию nom.-acc. dualis: не зависит от места ударения у существительных а-склонения (укр.дв'í руц'í, дв'í д'íвц'i) 0.4708686063882763
# Том 3, карта 5.1, ареал 1 *-ě  в твердой разновидности а-склонения независимо от места ударения (укр. дв'í руц'í, дв'í д'íвц'i, бел. дз'в'é руцэ́, дз'в'é дз'éўцэ, рус. д'в'é рук'é, д'в'é д'éвк'Е); 0.4626585603842978
# Том 2, карта 8.1, ареал 14 Р. землѣ, Д.-М. земли (укр.: зем[л'i], зем[ли], или полесск. зем[л'iе], зем[лi]) 0.42163317163317166
# Том 2, карта 16, ареал 8 когут 0.4122285361878331
# Том 3, карта 13.2, ареал 3 укр. б'л'аха 0.3981649924859606
# Том 1, карта 3, ареал 12 /и/: гост[и́]й, люд[и́]й и т.п. 0.39664970313825276
# Том 2, карта 10, ареал 3 бел. по лясох, укр. по лiсох 0.3941414141414141
# Том 3, карта 6, ареал 8 <ами> в отдельных словах 0.35680989914399525
#
# 10792
# Том 4, карта 7.3, ареал 11 рус. тепи́нка, цепи́нка; 0.3671685985628137
# Том 3, карта 14.2, ареал 4 суфф. =аv=ьl= (mur-av-ьl-ь) 0.26276207839562443
# Том 2, карта 18.1, ареал 12 велёк 0.2538181558664002
# Том 1, карта 14.1, ареал 1 +d'užE 0.21250750850964426
# Том 3, карта 6, ареал 11 изоглосса расширенного <м’и> 0.20449851249692078
# Том 4, карта 7.2, ареал 4 рус. держа́лень, держа́лка, держа́к;   укр. держа́к; 0.20099828652313192
# Том 4, карта 2.1, ареал 3 диссимилятивное аканье 0.18709554625047584
# Том 2, карта 8.1, ареал 16 Р., Д., М. земли (рус. земли, укр. галицк. земли, бел. зямлi) 0.17312952534191473
# Том 2, карта 8.1, ареал 3 Р. беспредложный жены, коровы, Р. предложный, Д., М. женѣ, коровѣ (рус.) 0.15136443777795322
# Том 4, карта 2.2, ареал 3 диссимилятивное яканье 0.14602408981905385
#
# 16679
# Том 3, карта 7.2, ареал 13 зона, в отдельных говорах которой отмечено одно местоимение для указания на ближний и отдаленный предмет:   тот или э́тот 0.29570738734893154
# Том 1, карта 4, ареал 8 *’а, *ę > Е (перед мягким согласным) // А (перед твердым согласным); примеры: p'ét', p’átyj, s’ádu, s’éd’eš, instr. pn’émi, dat. pn’ám, gul’él’i, gul’át, s’c'és’jö ‘счастье’ 0.29136093303467986
# Том 2, карта 13, ареал 7 отмечены (наряду с конструкциями типа рус. две косы́) конструкции типа рус. две ко́сы 0.25948737385701426
# Том 4, карта 7.1, ареал 2 рус. молоти́ло; 0.21414738825499843
# Том 1, карта 2, ареал 4 л → у в позициях перед согласным и на конце слова 0.2098102600140548
# Том 3, карта 3.1, ареал 4 Нестяженные окончания без [j] (зона преимущественного распространения):   -[аа], -[yy] -[оо], -[ое], -[оа], -[ые], -[ие] и др.    (рус. молод[а́a] и т.п., но́в[аа] и т.п., молод[у́у] и т.п., но́в[уу] и т.п., молод[о́e], молод[о́o] или молод[о́a] и т.п., кра́сн[ое], кра́сн[оо] или кра́сн[оа] и т.п., молод[ы́е], глу[х'и́е] и т.п., но́в[ые], си́[н'ие] и т.п.). 0.20439199539232628
# Том 3, карта 3.1, ареал 3 Граница разреженного распространения стяженных окончаний. 0.2033635413035901
# Том 4, карта 2.2, ареал 8 изменение предударного ’а > е, i перед мягким согласным 0.19843739506145203
# Том 4, карта 7.3, ареал 14 рус. па́лка; 0.1964169449520089
# Том 3, карта 1.1, ареал 1 *ě → ę, i͜ę 0.18765384367549456
#
# 5584
# Том 1, карта 4, ареал 2 после j: Е (jéma, jéstr’ib); после шипящего: Е (ž'éba, ž'éti); после губного или зубного согласного: Е (l'ék, l'l'éty); после r: Е (r(')éd) 0.4281091077207582
# Том 2, карта 5, ареал 6 <mn' ~ m'/m> = <1 л. ед., 3 л. мн.> ~ <2, 3 л. ед.. 1, 2 л. мн.> в глаголах с основой на /м/, например, укр. диал. кормн'у́, ко́рмн'ат' ~ ко́рмиш... 0.40696222291601625
# Том 3, карта 7.2, ареал 11 [с'ой] 0.2514222283890662
# Том 3, карта 13.1, ареал 3 репрезентанты sošnik 0.20313298144049038
# Том 2, карта 17, ареал 2 běl-ic-a 0.15973473063697397
# Том 3, карта 13.2, ареал 7 укр. зак'р'ii̯, бел. закр'и́й 0.14732354334438655
# Том 1, карта 3, ареал 4 /и/: молод[ы́]й, глу[х'и́]й, глух[ы́]й и т.п. и молод[ы́] и т.д. и т.п. 0.14303195105370498
# Том 2, карта 11, ареал 2 преимущественное употребление род. п. в конструкциях типа укр. уз'аў ножá, бел. знайшоў гры́ба 0.12401448020076843
# Том 2, карта 18.1, ареал 5 прач 0.12032620053609559
# Том 1, карта 13, ареал 15 бел. цмок; укр. смик; 0.11967847573682644

# %% [markdown]
# Близость к набору признаков

# %%
Rog_cart = stck.reshape((984, 969, stck.shape[-1]))[649, 618]

# %%
Rog_corp = np.array(list("...")).astype("int")

# %%
distances = np.array(list(map(lambda x: np.array([distance.euclidean(X[x], Rog_cart), 
                                                  distance.euclidean(X[x], Rog_corp)]), 
                              range(X.shape[0]))))

# %%
norm_distances = (distances - distances.min()) / (distances.max() - distances.min())

# %%
for ind, comp in {0: "dot", 1: "corp"}.items():
    cmap = color_palette("inferno_r", as_cmap=True)
    heat_rgb = cmap(norm_distances[:, ind]) * 255

    new_image = np.zeros((stck.shape[0], 4))
    new_image[positions] = heat_rgb
    res = new_image.reshape((984, 969, 4))
    res = Image.fromarray(res.astype(np.uint8))
    res.save(f"proximity_to_{comp}.png")

# %%
spearmanr(Rog_cart, Rog_corp)
# Out:
# SignificanceResult(statistic=0.6578012169312458, pvalue=1.2725211865789325e-56)

# %%
kendalltau(Rog_cart, Rog_corp)
# Out:
# SignificanceResult(statistic=0.6578012169312457, pvalue=8.81405271273025e-44)

# %%
contingency_table = pd.crosstab(Rog_cart, Rog_corp)

# %%
chi2, p, dof, expected = chi2_contingency(contingency_table)

# %%
np.sqrt(chi2 / Bud_cart.shape[0])
# Out:
# 0.6498246170739501
